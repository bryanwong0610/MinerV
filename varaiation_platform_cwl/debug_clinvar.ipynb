# %%
import pandas as pd
import numpy as np
import os

# %%
from pandas import read_table

clinvar_test = read_table('GRCh37_clinvar_20220719.txt')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
clinvar_test
# Out:
#         #Chr   Start     End Ref Alt  CLNALLELEID                      CLNDN  \
# 0          1  861332  861332   G   A      1003021               not_provided
# 1          1  861336  861336   C   T      1632777               not_provided
# 2          1  861349  861349   C   T      1600580               not_provided
# 3          1  861356  861356   T   C      1396033               not_provided
# 4          1  861366  861366   C   T      1570515               not_provided
# ...      ...     ...     ...  ..  ..          ...                        ...
# 1467797   MT   16159   16159   C   A      1517317  Mitochondrial_inheritance
# 1467798   MT   16180   16181  AA   -      1517353  Mitochondrial_inheritance
# 1467799   MT   16230   16230   A   G      1517319  Mitochondrial_inheritance
# 1467800   MT   16274   16274   G   A      1517318  Mitochondrial_inheritance
# 1467801   MT   16319   16319   G   A      1517668  Mitochondrial_inheritance
#
# ...
