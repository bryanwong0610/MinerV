# %%
import numpy as np
import pandas as pd

# %%
raw_annovar_dt=pd.read_table('test.cml.hg19_multianno.txt')

# %%
raw_annovar_dt
# Out:
#         Chr     Start       End Ref           Alt    Func.refGene  \
# 0      chr1     13418     13418   G             A    ncRNA_exonic
# 1      chr1     13649     13649   G             C    ncRNA_exonic
# 2      chr1     13657     13658  AG             -    ncRNA_exonic
# 3      chr1     13752     13752   T             C    ncRNA_exonic
# 4      chr1     13868     13868   A             G    ncRNA_exonic
# ...     ...       ...       ...  ..           ...             ...
# 62992  chrY  21154701  21154701   -  GGCCGGACGCTC  ncRNA_intronic
# 62993  chrY  21154779  21154779   C             G  ncRNA_intronic
# 62994  chrY  21154904  21154904   C             T  ncRNA_intronic
# 62995  chrY  21154937  21154937   G             A  ncRNA_intronic
# 62996  chrY  21154966  21154966   C             G  ncRNA_intronic
#
#       Gene.refGene GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0          DDX11L1                  .                  .                .
# ...

# %%
raw_annovar_dt["Func.ensGene"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            intergenic
# 1            intergenic
# 2            intergenic
# 3            intergenic
# 4            intergenic
#               ...
# 62992    ncRNA_intronic
# 62993    ncRNA_intronic
# 62994    ncRNA_intronic
# 62995    ncRNA_intronic
# 62996    ncRNA_intronic
# Name: Func.ensGene, Length: 62997, dtype: object>

# %%
raw_annovar_dt["Func.ensGene"].value_counts()
# Out:
# exonic                   24685
# UTR3                     11529
# ncRNA_exonic              9516
# intron                    6945
# intergenic                4182
# ncRNA_intronic            2785
# intronic                  1381
# upstream                   856
# splicing                   433
# downstream                 404
# exonic;splicing             78
# ncRNA_splicing              72
# upstream;downstream         66
# UTR5                        44
# ncRNA_exonic;splicing       20
# UTR5;UTR3                    1
# Name: Func.ensGene, dtype: int64

# %%
raw_annovar_dt['Func.refGene'].value_counts()
# Out:
# exonic                   25201
# ncRNA_exonic             15268
# UTR3                     12352
# intron                    7774
# ncRNA_intronic             634
# intronic                   478
# splicing                   397
# upstream                   345
# downstream                 195
# intergenic                 153
# ncRNA_splicing             110
# UTR5                        42
# exonic;splicing             20
# upstream;downstream         18
# ncRNA_exonic;splicing        8
# ncRNA_UTR5                   2
# Name: Func.refGene, dtype: int64

# %%
annotated_dt=pd.read_table('annotated.txt')

# %%
# Out:
#         Chr     Start       End Ref           Alt    Func.refGene  \
# 0      chr1     13418     13418   G             A    ncRNA_exonic
# 1      chr1     13649     13649   G             C    ncRNA_exonic
# 2      chr1     13657     13658  AG             -    ncRNA_exonic
# 3      chr1     13752     13752   T             C    ncRNA_exonic
# 4      chr1     13868     13868   A             G    ncRNA_exonic
# ...     ...       ...       ...  ..           ...             ...
# 62992  chrY  21154701  21154701   -  GGCCGGACGCTC  ncRNA_intronic
# 62993  chrY  21154779  21154779   C             G  ncRNA_intronic
# 62994  chrY  21154904  21154904   C             T  ncRNA_intronic
# 62995  chrY  21154937  21154937   G             A  ncRNA_intronic
# 62996  chrY  21154966  21154966   C             G  ncRNA_intronic
#
#       Gene.refGene GeneDetail.refGene ExonicFunc.refGene AAChange.refGene  \
# 0          DDX11L1                  .                  .                .
# ...

# %%
annotated_dt

# %%
col_type=annotated_dt.dtypes

# %%
col_type.to_csv('col_type.csv')

# %%
annotated_dt['1000G_AFR'].value_counts()
# Out:
# .        12650
# 1.        1805
# 0.99       803
# 0.13       615
# 0.12       614
#          ...
# 0.094       34
# 0.038       34
# 0.099       32
# 0.052       30
# 0.078       23
# Name: 1000G_AFR, Length: 194, dtype: int64

# %%
annotated_dt['AF'].value_counts()
# Out:
# .         30415
# 1.0000      227
# 1           162
# 0           160
# 0.0002      141
#           ...
# 0.2045        1
# 0.6051        1
# 0.2790        1
# 0.7602        1
# 0.7014        1
# Name: AF, Length: 9755, dtype: int64

# %%
my=annotated_dt['AF_afr'].str.contains("e")

# %%
my.value_counts()
# Out:
# False    62788
# True       209
# Name: AF_afr, dtype: int64
